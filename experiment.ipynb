# %%
import job_matcher
    
dir(job_matcher)

# %%
from job_matcher import search_candidates

# %%
jd = open("jobs/job1.txt").read()

jd

# %%
results = search_candidates(jd)

results

# %%
import time

start = time.time()

search_candidates(jd)

print("Latency:", time.time() - start)
